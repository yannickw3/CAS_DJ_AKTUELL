# %% [markdown]
# # GRUPPE 1
# 1. Alle italienische Restaurant scrapen und als .csv bei Slack teilen.
# 2. In welchen der 20 grössten Schweizer Städte, gibt (laut Google Maps) die meisten teueren italienischen Restaurants?

# %%
import requests
import pandas as pd
import time

# %%
t = pd.read_html("https://de.wikipedia.org/wiki/Liste_der_St%C3%A4dte_in_der_Schweiz#St%C3%A4dte_mit_mindestens_10'000_Einwohnern")

def citynames(elem):
    elem = elem.replace(" 1","").replace(" 2", "").replace(" / 3","")
    return elem
cities = list(t[0][1:][1].apply(citynames))

# %%
new_list = []

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=italienische+restaurants+in+"
fields = "fields=formatted_address,name,rating,price_level,pagetoken&"
locationbias = "locationbias=point:lat,lng&"
key = "key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&"
pagetoken = ''

for city in cities[:5]:
    result = range(4)
    while len(result) > 3: 
    
        print(len(result))
        api_query = url+query+city+"&"+fields+locationbias+key+pagetoken
        print(api_query)
        time.sleep(2)
        r = requests.get(api_query)
        result = r.json()
        print(len(result))
    
        for elem in result['results']:
            address = elem['formatted_address']
            name = elem['name']
            rating = elem['rating']
            if 'price_level' in elem:
                price_level = elem['price_level']
            else:
                price_level = 'unknown'
            lat = elem['geometry']['location']['lat']
            long = elem['geometry']['location']['lng']
    
            mini_dict = {'Addresse': address, 
                     'Name': name,
                     'Rating': rating,
                     'Preis': price_level,
                     'Lng':long,
                        'city': city}
    
            new_list.append(mini_dict)
        
    
        if len(result) > 3:
            pagetoken = 'pagetoken='+result['next_page_token'] 
        else:
            pagetoken = ''
            break
# Out:
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Zürich&fields=formatted_address,name,rating,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 4
# 4
# ...

# %%
df = pd.DataFrame(new_list)
df = df.drop_duplicates()

# %%
df_with_price = df[df['Preis'] != 'unknown']
df_with_price.head(20)
# Out:
#                                               Addresse       Lng  \
# 42        Kanzleistrasse 103, 8004 Zürich, Switzerland  8.522207
# 43             Schmidgasse 3, 8001 Zürich, Switzerland  8.543548
# 44       Kasernenstrasse 77A, 8004 Zürich, Switzerland  8.533836
# 45     Stampfenbachstrasse 6, 8001 Zürich, Switzerland  8.543925
# 47           Bertastrasse 36, 8003 Zürich, Switzerland  8.513545
# 48             Seestrasse 82, 8002 Zürich, Switzerland  8.531861
# 49    Mutschellenstrasse 137, 8038 Zürich, Switzerland  8.528694
# 51           Hardstrasse 324, 8005 Zürich, Switzerland  8.522853
# 54            Langstrasse 35, 8004 Zürich, Switzerland  8.525040
# 55          Brauerstrasse 87, 8004 Zürich, Switzerland  8.524119
# 56   Eingang Langwiesenstr., Birchstrasse 147, 8050...  8.537688
# 58           Cramerstrasse 8, 8004 Zürich, Switzerland  8.526123
# 59          Riedtlistrasse 2, 8006 Zürich, Switzerland  8.539981
# ...

# %%
df_with_price[df_with_price['Preis']>=3].groupby('city')['Preis'].count()
# Out:
# city
# Zürich    1
# Name: Preis, dtype: int64

# %%
# df_with_price.to_csv('Die_teuersten_Italiener.csv')

# %% [markdown]
# # GRUPPE 2
# 1. Alle indischen Restaurants scrapen und als .csv bei Slack teilen.
# 2. In welcher nach Bevölkerung Top 20 Stadt gibt es die besten indischen Restaurants?

# %%
new_list2 = []

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=indische+restaurants+in+"
fields = "fields=formatted_address,name,rating,pagetoken&"
locationbias = "locationbias=point:lat,lng&"
key = "key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&"
pagetoken = ''

for city in cities[:5]:
    result = range(4)
    while len(result) > 3: 
    
        print(len(result))
        api_query = url+query+city+"&"+fields+locationbias+key+pagetoken
        print(api_query)
        time.sleep(2)
        r = requests.get(api_query)
        result = r.json()
        print(len(result))
    
        for elem in result['results']:
            address = elem['formatted_address']
            name = elem['name']
            rating = elem['rating']
            lat = elem['geometry']['location']['lat']
            long = elem['geometry']['location']['lng']
    
            mini_dict = {'Addresse': address, 
                     'Name': name,
                     'Rating': rating,
                     'Lng':long,
                        'city': city}
    
            new_list2.append(mini_dict)
        
    
        if len(result) > 3:
            pagetoken = 'pagetoken='+result['next_page_token'] 
        else:
            pagetoken = ''
            break
# Out:
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Zürich&fields=formatted_address,name,rating,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 4
# 4
# ...

# %%
df_2 = pd.DataFrame(new_list2)
df_3 = df_2.drop_duplicates()
df_3
# Out:
#                                               Addresse       Lng  \
# 0          Klingenstrasse 33, 8005 Zürich, Switzerland  8.533625
# 1          Seefeldstrasse 96, 8008 Zürich, Switzerland  8.552528
# 2       Hofwiesenstrasse 188, 8057 Zürich, Switzerland  8.535317
# 3    Schaffhauserstrasse 306, 8050 Zürich, Switzerland  8.548218
# 4    Schaffhauserstrasse 410, 8050 Zürich, Switzerland  8.545811
# 5      Wallisellenstrasse 11, 8050 Zürich, Switzerland  8.548490
# 6      Stauffacherstrasse 27, 8004 Zürich, Switzerland  8.528926
# 7    Tadka Indisches Restaurant, Quellenstrasse 49,...  8.528704
# 8        Zypressenstrasse 52, 8004 Zürich, Switzerland  8.513121
# 9     Schaffhauserstrasse 32, 8006 Zürich, Switzerland  8.539215
# 10           Langstrasse 213, 8005 Zürich, Switzerland  8.530098
# 11         Seefeldstrasse 7A, 8008 Zürich, Switzerland  8.548724
# 12         Kanzleistrasse 78, 8004 Zürich, Switzerland  8.524385
# ...

# %%
df_3.sort_values('Rating', ascending=False).head(5)
# Out:
#                                             Addresse       Lng  \
# 64  Boulevard Carl-Vogt 62, 1205 Genève, Switzerland  6.136010
# 91           Moserstrasse 27, 3014 Bern, Switzerland  7.452594
# 77      St. Johanns-Ring 34, 4056 Basel, Switzerland  7.578186
# 30     Beckenhofstrasse 16, 8006 Zürich, Switzerland  8.541905
# 44      Rue de Monthoux 58, 1201 Genève, Switzerland  6.145726
#
#                     Name  Rating    city
# 64  Restaurant Le Safran     4.9    Genf
# 91       3dosha ayurveda     4.9    Bern
# 77         Johann by Jay     4.7   Basel
# 30          Curry Corner     4.7  Zürich
# 44          Indian Plaza     4.6    Genf

# %% [markdown]
# # GRUPPE 3
# 1. Alle französischen Restaurants scrapen und als .csv bei Slack teilen.
# 2. Wo gibt es die besten französischen Restaurants?

# %% [markdown]
# # GRUPPE 4
# 1. Alle vietnamesichen Restaurants scrapen und als .csv bei Slack teilen.
# 2. Wo gibt es pro Kopf die meisten vietnamesischen Restaurants?

# %%
def einwohner(elem):
    elem = elem.replace("'","")
    return int(elem)
einwohner = list(t[0][1:][6].apply(einwohner))

# %%
vietnam_restis = []

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=vietnamesische+restaurants+in+"
fields = "fields=formatted_address,name,rating,pagetoken&"
locationbias = "locationbias=point:lat,lng&"
key = "key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&"
pagetoken = ''

for city, einwohn in zip(cities[:20], einwohner[:20]):
    result = range(4)
    while len(result) > 3: 
    
        print(len(result))
        api_query = url+query+city+"&"+fields+locationbias+key+pagetoken
        print(api_query)
        time.sleep(2)
        r = requests.get(api_query)
        result = r.json()
        print(len(result))
    
        for elem in result['results']:
            address = elem['formatted_address']
            name = elem['name']
            rating = elem['rating']
            lat = elem['geometry']['location']['lat']
            long = elem['geometry']['location']['lng']
    
            mini_dict = {'Addresse': address, 
                     'Name': name,
                     'Rating': rating,
                     'Lng':long,
                        'city': city,
                        'einwohner': einwohn}
    
            vietnam_restis.append(mini_dict)
        
    
        if len(result) > 3:
            pagetoken = 'pagetoken='+result['next_page_token'] 
        else:
            pagetoken = ''
            break
# Out:
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Zürich&fields=formatted_address,name,rating,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Genf&fields=formatted_address,name,rating,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Basel&fields=formatted_address,name,rating,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Bern&fields=formatted_address,name,rating,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# ...

# %%
df_viet = pd.DataFrame(vietnam_restis)
df_vietnam = df_viet.drop_duplicates()
df_vietnam
# Out:
#                                               Addresse       Lng  \
# 0        Uetlibergstrasse 77, 8045 Zürich, Switzerland  8.518665
# 1             Langstrasse 13, 8004 Zürich, Switzerland  8.524481
# 2         Gasometerstrasse 7, 8005 Zürich, Switzerland  8.528473
# 3             Sihlstrasse 97, 8001 Zürich, Switzerland  8.532775
# 4        Zypressenstrasse 50, 8004 Zürich, Switzerland  8.512907
# 5           Kehlhofstrasse 4, 8003 Zürich, Switzerland  8.518454
# 6    Schwamendingenstrasse 10, 8050 Zürich, Switzer...  8.547129
# 7    Schaffhauserstrasse 127, 8057 Zürich, Switzerland  8.540545
# 8    Schaffhauserstrasse 475, 8052 Zürich, Switzerland  8.548364
# 9            Josefstrasse 42, 8005 Zürich, Switzerland  8.532984
# 10   Birmensdorferstrasse 126, 8003 Zürich, Switzer...  8.520779
# 11           Rolandstrasse 9, 8004 Zürich, Switzerland  8.526647
# 12   Leutschenbachstrasse 71, 8050 Zürich, Switzerland  8.556720
# ...

# %%
df_vietnam.dtypes
# Out:
# Addresse      object
# Lng          float64
# Name          object
# Rating       float64
# city          object
# einwohner      int64
# dtype: object

# %%
# Alternative, wenn man die Spalte City noch nicht hätte:

def findcity(elem):
    for city in cities[:10]:
        if city in elem:
            return True
            break
        else:
            return False

# %%
df_vietnam['city'].value_counts()
# Out:
# Lugano               60
# Uster                46
# Zürich               17
# Genf                  9
# Chur                  8
# Neuenburg             8
# Lausanne              7
# Thun                  7
# La Chaux-de-Fonds     6
# Schaffhausen          6
# Basel                 5
# Bern                  5
# St. Gallen            2
# Luzern                2
# Köniz                 1
# Freiburg              1
# Winterthur            1
# Biel/Bienne           1
# Name: city, dtype: int64

# %% [markdown]
# # GRUPPE 5
# 1. Alle Fonduestüblis scrapen und als .csv bei Slack teilen.
# 2. Wo gibt es die Fonduestüblis mit der besten Athmosphäre?
